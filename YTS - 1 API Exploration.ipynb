# %% [markdown]
# # Experiment: 1. API Exploration
#
# Dependencies
# - google-api-python-client
# - google-auth-oauthlib
# - google-auth-httplib
#
# Requirements
# - Create a [Google API Console Project and API Key](https://developers.google.com/youtube/v3/quickstart/python)

# %%
# This is an example that was obtained from here:
# https://medium.com/mcd-unison/youtube-data-api-v3-in-python-tutorial-with-examples-e829a25d2ebd#5999

# IMPORTS
import json
import numpy as np
import pandas as pd
# API client library
import googleapiclient.discovery

# API information
api_service_name = "youtube"
api_version = "v3"

# API key
with open('dev.key') as f:
    DEVELOPER_KEY = f.readline()

# API client
youtube = googleapiclient.discovery.build(
    api_service_name, 
    api_version, 
    developerKey = DEVELOPER_KEY)

# Query String
query_string = "dungeon synth archives"
    
# Query Paramters
# TODO

# 'request' variable is the only thing you must change
# depending on the resource and method you need to use
# in your query
request = youtube.search().list(
    part="snippet",
    maxResults=25,
    q=query_string
)

# Query execution
response = request.execute()

# %%
response
# Out:
# {'kind': 'youtube#searchListResponse',
#  'etag': 'ghvW2h8sE-BKaf5Nn-KFHmJpkj0',
#  'nextPageToken': 'CBkQAA',
#  'regionCode': 'PT',
#  'pageInfo': {'totalResults': 27673, 'resultsPerPage': 25},
#  'items': [{'kind': 'youtube#searchResult',
#    'etag': 'Rm7TrVYGNYWBwV7CBH3zZsngyH8',
#    'id': {'kind': 'youtube#channel', 'channelId': 'UChmm356a5qe1luUsoatAgjA'},
#    'snippet': {'publishedAt': '2015-11-21T13:20:19Z',
#     'channelId': 'UChmm356a5qe1luUsoatAgjA',
#     'title': 'The Dungeon Synth Archives',
#     'description': 'Welcome on The Dungeon Synth Archives ! Here you will find uploads of old, rare and new dungeon synth albums. The goal of ...',
#     'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/ytc/AMLnZu8yKhv4_b68iOp4EIoeH1y7eMrTsPcOTQ_9z08p6g=s88-c-k-c0xffffffff-no-rj-mo'},
#      'medium': {'url': 'https://yt3.ggpht.com/ytc/AMLnZu8yKhv4_b68iOp4EIoeH1y7eMrTsPcOTQ_9z08p6g=s240-c-k-c0xffffffff-no-rj-mo'},
#      'high': {'url': 'https://yt3.ggpht.com/ytc/AMLnZu8yKhv4_b68iOp4EIoeH1y7eMrTsPcOTQ_9z08p6g=s800-c-k-c0xffffffff-no-rj-mo'}},
#     'channelTitle': 'The Dungeon Synth Archives',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2015-11-21T13:20:19Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'hpnc4ST2oAV93DymTOCxyfd8fO4',
#    'id': {'kind': 'youtube#video', 'videoId': 'qqDyoqB7Nj0'},
#    'snippet': {'publishedAt': '2022-12-06T17:42:37Z',
#     'channelId': 'UChmm356a5qe1luUsoatAgjA',
#     'title': 'Knights of Nvrul - Knightronauts (2022) (Dungeon Synth)',
#     'description': 'Artist : Knights of Nvrul Album : Knightronauts Year : 2022 Genre : Dungeon Synth, Dark Ambient, Fantasy Ambient Country ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/qqDyoqB7Nj0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/qqDyoqB7Nj0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/qqDyoqB7Nj0/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'The Dungeon Synth Archives',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-12-06T17:42:37Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'cx9evNnFovxqxtAU-z5W9fbugvI',
#    'id': {'kind': 'youtube#video', 'videoId': 'Pe8eBeGtJ_w'},
#    'snippet': {'publishedAt': '2017-01-11T19:45:10Z',
#     'channelId': 'UChmm356a5qe1luUsoatAgjA',
#     'title': 'Vindkaldr - Ambient I (2015) (Dungeon Synth)',
#     'description': 'Artist : Vindkaldr Album : Ambient I Year : 2015 Genre : Dungeon Synth Country : Australia TRACKLIST : 01. Moon Snatcher 00:00 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Pe8eBeGtJ_w/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/Pe8eBeGtJ_w/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/Pe8eBeGtJ_w/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'The Dungeon Synth Archives',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2017-01-11T19:45:10Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '1IhzGOYzXCDHo_3ooA09HVsTAqQ',
#    'id': {'kind': 'youtube#video', 'videoId': '1LbciQTAjJw'},
#    'snippet': {'publishedAt': '2017-01-13T17:43:11Z',
#     'channelId': 'UChmm356a5qe1luUsoatAgjA',
#     'title': 'Vindkaldr - Enchantments Of Old Lore (2015) (Dungeon Synth, Medieval Dark Ambient)',
#     'description': 'Artist : Vindkaldr Album : Enchantments Of Old Lore Year : 2015 Genre : Dungeon Synth, Medieval Dark Ambient Country ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/1LbciQTAjJw/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/1LbciQTAjJw/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/1LbciQTAjJw/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'The Dungeon Synth Archives',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2017-01-13T17:43:11Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '9_5YXPpvXHN5yHjBRSxhsosX_qg',
#    'id': {'kind': 'youtube#video', 'videoId': 'dI7tjPGEz7U'},
#    'snippet': {'publishedAt': '2022-06-07T17:16:22Z',
#     'channelId': 'UChmm356a5qe1luUsoatAgjA',
#     'title': 'Tales Under The Oak - The Toad King (2021) (Dungeon Synth)',
#     'description': 'Artist : Tales Under The Oak Album : The Toad King Year : 2021 Genre : Dungeon Synth, Medieval Ambient Country : Germany ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/dI7tjPGEz7U/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/dI7tjPGEz7U/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/dI7tjPGEz7U/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'The Dungeon Synth Archives',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-06-07T17:16:22Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'b6g_goPEoMC0PqJr5k0XeV1fMZI',
#    'id': {'kind': 'youtube#video', 'videoId': 'x8TGp13ZzIA'},
#    'snippet': {'publishedAt': '2019-12-09T21:30:10Z',
#     'channelId': 'UChmm356a5qe1luUsoatAgjA',
#     'title': '2 Hours of Winter Synth &amp; Dark Ambient - Dungeon Synth Playlist',
#     'description': 'THUMBNAIL ART BY WILHELM STEUERWALDT *Örnatorpet - Över Frusen Mark - II 00:00 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/x8TGp13ZzIA/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/x8TGp13ZzIA/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/x8TGp13ZzIA/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'The Dungeon Synth Archives',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2019-12-09T21:30:10Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'BtLbhPygolj89m1_BVJrUYae6wY',
#    'id': {'kind': 'youtube#video', 'videoId': 'gBmz4O41jfc'},
#    'snippet': {'publishedAt': '2022-09-26T16:43:05Z',
#     'channelId': 'UChmm356a5qe1luUsoatAgjA',
#     'title': 'Old Tower - Tales of the Mad Moon (2021) (Old-School Dungeon Synth)',
#     'description': 'Artist : Old Tower Album : Tales of the Mad Moon Year : 2021 Genre : Old-School Dungeon Synth, Medieval Ambient Country ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/gBmz4O41jfc/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/gBmz4O41jfc/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/gBmz4O41jfc/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'The Dungeon Synth Archives',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-09-26T16:43:05Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '1pwdzPvHisiIAAOs4FdYFoITn-M',
#    'id': {'kind': 'youtube#video', 'videoId': 'BkDyoi-eFUw'},
#    'snippet': {'publishedAt': '2022-11-17T19:22:08Z',
#     'channelId': 'UChmm356a5qe1luUsoatAgjA',
#     'title': 'Frost Clad - The Bastion of Pines (2022) (Dungeon Synth)',
#     'description': 'Artist : Frost Clad Album : The Bastion of Pines Year : 2022 Genre : Dungeon Synth, Fantasy Ambient, Dark Ambient Country ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/BkDyoi-eFUw/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/BkDyoi-eFUw/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/BkDyoi-eFUw/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'The Dungeon Synth Archives',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-11-17T19:22:08Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'rbIqmfGpaoPTdR_DVW9it0zOYM8',
#    'id': {'kind': 'youtube#video', 'videoId': 'DffQVP6UqVQ'},
#    'snippet': {'publishedAt': '2017-02-16T11:07:08Z',
#     'channelId': 'UChmm356a5qe1luUsoatAgjA',
#     'title': 'Fief - II (2016) (Dungeon Synth)',
#     'description': 'Artist : Fief Album : II Year : 2016 Genre : Dungeon Synth Country : USA TRACKLIST : 1. Dawnlight Warms the Castle Stone 00:00 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/DffQVP6UqVQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/DffQVP6UqVQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/DffQVP6UqVQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'The Dungeon Synth Archives',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2017-02-16T11:07:08Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'C3k9v62nqr4bo71YSK-_lEGtl8U',
#    'id': {'kind': 'youtube#video', 'videoId': '1lpf-nQFzJ4'},
#    'snippet': {'publishedAt': '2016-07-02T15:31:21Z',
#     'channelId': 'UChmm356a5qe1luUsoatAgjA',
#     'title': 'Thangorodrim - Taur-nu-Fuin (2016) (Old-School Dungeon Synth)',
#     'description': 'Artist : Thangorodrim Album : Taur\u200b-\u200bnu\u200b-\u200bFuin Year : 2016 Genre : Dungeon Synth Country : USA TRACKLIST 1. In Hills of ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/1lpf-nQFzJ4/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/1lpf-nQFzJ4/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/1lpf-nQFzJ4/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'The Dungeon Synth Archives',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2016-07-02T15:31:21Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'shQcB22Wx1Rvo889MMnwbjsuyPk',
#    'id': {'kind': 'youtube#video', 'videoId': 'uTpRQS1LDiw'},
#    'snippet': {'publishedAt': '2016-07-12T23:44:16Z',
#     'channelId': 'UChmm356a5qe1luUsoatAgjA',
#     'title': 'Galdur -  Age of Legends (Dungeon Synth, Tolkien Inspired Epic Ambient)',
#     'description': 'Artist : Galdur Album : Age of Legends Year : 2016 Genre : Dungeon Synth, Tolkien Inspired Country : Ukraine TRACKLIST 01.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/uTpRQS1LDiw/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/uTpRQS1LDiw/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/uTpRQS1LDiw/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'The Dungeon Synth Archives',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2016-07-12T23:44:16Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'I7vGXFj0orM9nIRAgB8eQO-sBLI',
#    'id': {'kind': 'youtube#video', 'videoId': 'ngRcnobJxi4'},
#    'snippet': {'publishedAt': '2022-08-28T19:15:50Z',
#     'channelId': 'UChmm356a5qe1luUsoatAgjA',
#     'title': 'Frér - Crepuscular Glare Of Wisdom (2022) (Dungeon Synth, Fantasy Ambient)',
#     'description': 'Artist: Frér Album: Crepuscular Glare Of Wisdom Year: 2022 Genre: Dungeon Synth, Fantasy Ambient Country: Italy Label: Moonlit ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/ngRcnobJxi4/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/ngRcnobJxi4/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/ngRcnobJxi4/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'The Dungeon Synth Archives',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-08-28T19:15:50Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'RawnAK1L_TejvnSHPGPmKLwM3CI',
#    'id': {'kind': 'youtube#video', 'videoId': 'fpz7GNig8IU'},
#    'snippet': {'publishedAt': '2022-01-12T18:31:31Z',
#     'channelId': 'UChmm356a5qe1luUsoatAgjA',
#     'title': 'DIM - Compendium Reliquiae (2021) (Dungeon Synth, Medieval Ambient)',
#     'description': 'Artist : DIM Album : Compendium Reliquiae Year : 2021 Genre : Dungeon Synth, Medieval Ambient, Fantasy Ambient Country ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/fpz7GNig8IU/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/fpz7GNig8IU/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/fpz7GNig8IU/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'The Dungeon Synth Archives',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-01-12T18:31:31Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'cGC-rmQ2sWFp6Kx7mm_EeR55DK8',
#    'id': {'kind': 'youtube#video', 'videoId': 'OxgVmpAk538'},
#    'snippet': {'publishedAt': '2017-09-02T12:01:46Z',
#     'channelId': 'UChmm356a5qe1luUsoatAgjA',
#     'title': 'Depressive Silence - Depressive Silence II (1996) (Dungeon Synth, Black Ambient)',
#     'description': 'Artist : Depressive Silence Album : Depressive Silence II Year : 1996 Genre : Dungeon Synth, Black Ambient Country : Germany ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/OxgVmpAk538/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/OxgVmpAk538/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/OxgVmpAk538/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'The Dungeon Synth Archives',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2017-09-02T12:01:46Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'K1N1DhVnWhBT-dCQVdvLrPxWOc0',
#    'id': {'kind': 'youtube#video', 'videoId': 'XKSu-wZChcQ'},
#    'snippet': {'publishedAt': '2016-07-20T18:15:19Z',
#     'channelId': 'UChmm356a5qe1luUsoatAgjA',
#     'title': 'Secret Stairways - Enchantment of the Ring (1997) (Dungeon Synth)',
#     'description': 'Artist : Secret Stairways Album : Enchantment of the Ring Year : 1997 Genre : Dungeon Synth, Tolkien Inspired Country : USA ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/XKSu-wZChcQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/XKSu-wZChcQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/XKSu-wZChcQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'The Dungeon Synth Archives',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2016-07-20T18:15:19Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'gd4nR-OfF-mwXQtUQ7C35sh1Grk',
#    'id': {'kind': 'youtube#video', 'videoId': 'eKguSG6XAG8'},
#    'snippet': {'publishedAt': '2017-07-29T13:54:32Z',
#     'channelId': 'UChmm356a5qe1luUsoatAgjA',
#     'title': 'Bacchia Neraida - Dionysos (1997) (Black Ambient, Old-School Dungeon Synth)',
#     'description': 'Artist : Bacchia Neraida Album : Dionysos Year : 1997 Genre : Black Ambient, Old-School Dungeon Synth Country : Greece ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/eKguSG6XAG8/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/eKguSG6XAG8/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/eKguSG6XAG8/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'The Dungeon Synth Archives',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2017-07-29T13:54:32Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'zsNWtezOu7I7A3HDhu6tg9rpc9A',
#    'id': {'kind': 'youtube#video', 'videoId': '6aTalupHHrU'},
#    'snippet': {'publishedAt': '2022-12-02T20:00:53Z',
#     'channelId': 'UChmm356a5qe1luUsoatAgjA',
#     'title': 'Erang - A SEASON OF FROST / LEAVES / SAND / BLOOM / MAGIC (2022) (Dungeon Synth)',
#     'description': 'Artist : Erang Album : 10 Years Pentalogy Year : 2022 Genre : Dungeon Synth, Atmospheric Black Metal, New Age, Folk, Ambient ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/6aTalupHHrU/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/6aTalupHHrU/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/6aTalupHHrU/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'The Dungeon Synth Archives',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-12-02T20:00:53Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'cghbpJC5k08rxKxdYYfNvW8qxtY',
#    'id': {'kind': 'youtube#video', 'videoId': '2lS_Y-aNJwk'},
#    'snippet': {'publishedAt': '2019-03-02T11:35:05Z',
#     'channelId': 'UChmm356a5qe1luUsoatAgjA',
#     'title': 'Aindulmedir - The Lunar Lexicon (2019) (Dark Ambient, Dungeon Synth)',
#     'description': 'Artist : Aindulmedir Album : The Lunar Lexicon Year : 2019 Genre : Dark Ambient, Dungeon Synth, Winter Synth Country : Sweden ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/2lS_Y-aNJwk/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/2lS_Y-aNJwk/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/2lS_Y-aNJwk/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'The Dungeon Synth Archives',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2019-03-02T11:35:05Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'vwQpXeGWsWEBOZIuMz0IK7xLjeQ',
#    'id': {'kind': 'youtube#video', 'videoId': '66HmBxrTlrQ'},
#    'snippet': {'publishedAt': '2022-10-15T09:14:36Z',
#     'channelId': 'UChmm356a5qe1luUsoatAgjA',
#     'title': 'Old Tower - The Last Eidolon (2020) (Old-School Dungeon Synth)',
#     'description': 'Artist : Old Tower Album : The Last Eidolon Year : 2020 Genre : Old-School Dungeon Synth, Medieval Ambient Country ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/66HmBxrTlrQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/66HmBxrTlrQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/66HmBxrTlrQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'The Dungeon Synth Archives',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-10-15T09:14:36Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'dvCaNBjx5D4Ty3xij67521I_1fo',
#    'id': {'kind': 'youtube#video', 'videoId': 'ZLqAdISGYR8'},
#    'snippet': {'publishedAt': '2016-07-25T20:20:56Z',
#     'channelId': 'UChmm356a5qe1luUsoatAgjA',
#     'title': 'Mordraaneth - The Taverns in the Land of Ashes (2007) (Dungeon Synth)',
#     'description': 'Artist : Mordraaneth Album : The Taverns in the Land of Ashes Year : 2007 Genre : Dungeon Synth Country : United-Kingdom ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/ZLqAdISGYR8/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/ZLqAdISGYR8/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/ZLqAdISGYR8/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'The Dungeon Synth Archives',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2016-07-25T20:20:56Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '7Ta6xllJETsEGVB4C5UR1yjDhcw',
#    'id': {'kind': 'youtube#video', 'videoId': 'xEXjwm-xLSw'},
#    'snippet': {'publishedAt': '2019-11-12T16:43:22Z',
#     'channelId': 'UChmm356a5qe1luUsoatAgjA',
#     'title': 'Monastery - The Garden Of Abandon (2019) (Dungeon Synth, Folk Ambient, Dark Ambient)',
#     'description': 'Artist : Monastery Album : The Garden Of Abandon Year : 2019 Genre : Dungeon Synth, Folk Ambient, Dark Ambient Country ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/xEXjwm-xLSw/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/xEXjwm-xLSw/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/xEXjwm-xLSw/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'The Dungeon Synth Archives',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2019-11-12T16:43:22Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'e6XySzrfjT2uhE1GcPoYTAqkDok',
#    'id': {'kind': 'youtube#video', 'videoId': 'E9R-vzIe8x0'},
#    'snippet': {'publishedAt': '2016-07-21T13:30:03Z',
#     'channelId': 'UChmm356a5qe1luUsoatAgjA',
#     'title': 'Secret Stairways - Turning Point (1999) (Dungeon Synth)',
#     'description': 'Artist : Secret Stairways Album : Turning Point Year : 1999 Genre : Dungeon Synth, Tolkien Inspired Country : USA TRACKLIST 01 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/E9R-vzIe8x0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/E9R-vzIe8x0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/E9R-vzIe8x0/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'The Dungeon Synth Archives',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2016-07-21T13:30:03Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'nfyPaJ7SZjqB2ctWYXQAG_FXPU0',
#    'id': {'kind': 'youtube#video', 'videoId': 'UzTqkmN79dU'},
#    'snippet': {'publishedAt': '2017-04-06T15:43:00Z',
#     'channelId': 'UChmm356a5qe1luUsoatAgjA',
#     'title': 'December&#39;s Fire \u200e- Across The Sorrowfields Of Baltic (1995) (Old-School Dungeon Synth)',
#     'description': "Artist : December's Fire \u200e Album : Across The Sorrowfields Of Baltic Year : 1995 Genre : Old-School Dungeon Synth Country ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/UzTqkmN79dU/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/UzTqkmN79dU/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/UzTqkmN79dU/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'The Dungeon Synth Archives',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2017-04-06T15:43:00Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'YrDYtbmr8v_2CFpwa1PpqXlHTmU',
#    'id': {'kind': 'youtube#video', 'videoId': 'uwwIB5uheNo'},
#    'snippet': {'publishedAt': '2022-09-15T16:45:12Z',
#     'channelId': 'UChmm356a5qe1luUsoatAgjA',
#     'title': 'Ortnit - Ortnit (2022) (Dungeon Synth) [OFFICIAL PREMIERE]',
#     'description': 'Artist : Ortnit (side project of Thomas Helm from Empyrium) Album : Ortnit Year : 2022 Genre : Dungeon Synth Country : Germany ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/uwwIB5uheNo/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/uwwIB5uheNo/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/uwwIB5uheNo/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'The Dungeon Synth Archives',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-09-15T16:45:12Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '8PacYDrqzVfbLXlpw82Yn-M-MEk',
#    'id': {'kind': 'youtube#video', 'videoId': 'lklHS1G9E-M'},
#    'snippet': {'publishedAt': '2020-04-05T14:35:24Z',
#     'channelId': 'UChmm356a5qe1luUsoatAgjA',
#     'title': 'Quest Master - Lost Songs of Distant Realms [Complete Collection] (2020) (Dungeon Synth)',
#     'description': 'Artist : Quest Master Album : Lost Songs of Distant Realms [Complete Collection] Year : 2020 Genre : Dungeon Synth, Chiptune, ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/lklHS1G9E-M/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/lklHS1G9E-M/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/lklHS1G9E-M/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'The Dungeon Synth Archives',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2020-04-05T14:35:24Z'}}]}

# %%
# Extract Results
total_results = response["pageInfo"]["totalResults"]
next_page_token = response["nextPageToken"]
items = response["items"]


# Print Results
print("Total Results: " + str(total_results))
result_list = []

for i in items:
    # Extract base data (only for VIDEOS - TODO: handle playlist and channels)
    result_kind = i["id"]["kind"]
    if(result_kind == "youtube#video"):
        kind = 'video'
        result_id = i["id"]["videoId"]
    elif(result_kind == "youtube#playlist"):
        kind = 'playlist'
        result_id = i["id"]["playlistId"]
    elif(result_kind == "youtube#channel"):
        kind = 'channel'
        result_id = i["id"]["channelId"]
    else:
        kind = 'unknown'
        result_id = i["id"][1]

    # Extract Snippet
    snippet = i["snippet"]
    channel_id = snippet["channelId"]
    channel_title = snippet["channelTitle"]
    channel_link = "https://www.youtube.com/channel/" + str(channel_id)
    title = snippet["title"]
    description = snippet["description"]
    date = snippet["publishedAt"]
    link = "https://www.youtube.com/watch?v=" + str(result_id)

    # Add to List
    result_list.append({
        'kind': kind,
        'id': result_id, 
        'channel_id': channel_id, 
        'channel_title': channel_title, 
        'channel_link': channel_link,
        'title': title, 
        'description': description, 
        'date': date, 
        'link': link
    })

result_df = pd.DataFrame(result_list)
result_df
# Out:
# Total Results: 27673
#         kind                        id                channel_id  \
# 0   playlist  UChmm356a5qe1luUsoatAgjA  UChmm356a5qe1luUsoatAgjA
# 1      video               qqDyoqB7Nj0  UChmm356a5qe1luUsoatAgjA
# 2      video               Pe8eBeGtJ_w  UChmm356a5qe1luUsoatAgjA
# 3      video               1LbciQTAjJw  UChmm356a5qe1luUsoatAgjA
# 4      video               dI7tjPGEz7U  UChmm356a5qe1luUsoatAgjA
# 5      video               x8TGp13ZzIA  UChmm356a5qe1luUsoatAgjA
# 6      video               gBmz4O41jfc  UChmm356a5qe1luUsoatAgjA
# 7      video               BkDyoi-eFUw  UChmm356a5qe1luUsoatAgjA
# 8      video               DffQVP6UqVQ  UChmm356a5qe1luUsoatAgjA
# 9      video               1lpf-nQFzJ4  UChmm356a5qe1luUsoatAgjA
# 10     video               uTpRQS1LDiw  UChmm356a5qe1luUsoatAgjA
# 11     video               ngRcnobJxi4  UChmm356a5qe1luUsoatAgjA
# 12     video               fpz7GNig8IU  UChmm356a5qe1luUsoatAgjA
# 13     video               OxgVmpAk538  UChmm356a5qe1luUsoatAgjA
# 14     video               XKSu-wZChcQ  UChmm356a5qe1luUsoatAgjA
# 15     video               eKguSG6XAG8  UChmm356a5qe1luUsoatAgjA
# 16     video               6aTalupHHrU  UChmm356a5qe1luUsoatAgjA
# 17     video               2lS_Y-aNJwk  UChmm356a5qe1luUsoatAgjA
# 18     video               66HmBxrTlrQ  UChmm356a5qe1luUsoatAgjA
# 19     video               ZLqAdISGYR8  UChmm356a5qe1luUsoatAgjA
# 20     video               xEXjwm-xLSw  UChmm356a5qe1luUsoatAgjA
# 21     video               E9R-vzIe8x0  UChmm356a5qe1luUsoatAgjA
# 22     video               UzTqkmN79dU  UChmm356a5qe1luUsoatAgjA
# 23     video               uwwIB5uheNo  UChmm356a5qe1luUsoatAgjA
# 24     video               lklHS1G9E-M  UChmm356a5qe1luUsoatAgjA
#
#                  channel_title  \
# 0   The Dungeon Synth Archives
# 1   The Dungeon Synth Archives
# 2   The Dungeon Synth Archives
# 3   The Dungeon Synth Archives
# 4   The Dungeon Synth Archives
# 5   The Dungeon Synth Archives
# 6   The Dungeon Synth Archives
# 7   The Dungeon Synth Archives
# 8   The Dungeon Synth Archives
# 9   The Dungeon Synth Archives
# 10  The Dungeon Synth Archives
# 11  The Dungeon Synth Archives
# 12  The Dungeon Synth Archives
# 13  The Dungeon Synth Archives
# 14  The Dungeon Synth Archives
# 15  The Dungeon Synth Archives
# 16  The Dungeon Synth Archives
# 17  The Dungeon Synth Archives
# 18  The Dungeon Synth Archives
# 19  The Dungeon Synth Archives
# 20  The Dungeon Synth Archives
# 21  The Dungeon Synth Archives
# 22  The Dungeon Synth Archives
# 23  The Dungeon Synth Archives
# 24  The Dungeon Synth Archives
#
#                                          channel_link  \
# 0   https://www.youtube.com/channel/UChmm356a5qe1l...
# 1   https://www.youtube.com/channel/UChmm356a5qe1l...
# 2   https://www.youtube.com/channel/UChmm356a5qe1l...
# 3   https://www.youtube.com/channel/UChmm356a5qe1l...
# 4   https://www.youtube.com/channel/UChmm356a5qe1l...
# 5   https://www.youtube.com/channel/UChmm356a5qe1l...
# 6   https://www.youtube.com/channel/UChmm356a5qe1l...
# 7   https://www.youtube.com/channel/UChmm356a5qe1l...
# 8   https://www.youtube.com/channel/UChmm356a5qe1l...
# 9   https://www.youtube.com/channel/UChmm356a5qe1l...
# 10  https://www.youtube.com/channel/UChmm356a5qe1l...
# 11  https://www.youtube.com/channel/UChmm356a5qe1l...
# 12  https://www.youtube.com/channel/UChmm356a5qe1l...
# 13  https://www.youtube.com/channel/UChmm356a5qe1l...
# 14  https://www.youtube.com/channel/UChmm356a5qe1l...
# 15  https://www.youtube.com/channel/UChmm356a5qe1l...
# 16  https://www.youtube.com/channel/UChmm356a5qe1l...
# 17  https://www.youtube.com/channel/UChmm356a5qe1l...
# 18  https://www.youtube.com/channel/UChmm356a5qe1l...
# 19  https://www.youtube.com/channel/UChmm356a5qe1l...
# 20  https://www.youtube.com/channel/UChmm356a5qe1l...
# 21  https://www.youtube.com/channel/UChmm356a5qe1l...
# 22  https://www.youtube.com/channel/UChmm356a5qe1l...
# 23  https://www.youtube.com/channel/UChmm356a5qe1l...
# 24  https://www.youtube.com/channel/UChmm356a5qe1l...
#
#                                                 title  \
# 0                          The Dungeon Synth Archives
# 1   Knights of Nvrul - Knightronauts (2022) (Dunge...
# 2        Vindkaldr - Ambient I (2015) (Dungeon Synth)
# 3   Vindkaldr - Enchantments Of Old Lore (2015) (D...
# 4   Tales Under The Oak - The Toad King (2021) (Du...
# 5   2 Hours of Winter Synth &amp; Dark Ambient - D...
# 6   Old Tower - Tales of the Mad Moon (2021) (Old-...
# 7   Frost Clad - The Bastion of Pines (2022) (Dung...
# 8                    Fief - II (2016) (Dungeon Synth)
# 9   Thangorodrim - Taur-nu-Fuin (2016) (Old-School...
# 10  Galdur -  Age of Legends (Dungeon Synth, Tolki...
# 11  Frér - Crepuscular Glare Of Wisdom (2022) (Dun...
# 12  DIM - Compendium Reliquiae (2021) (Dungeon Syn...
# 13  Depressive Silence - Depressive Silence II (19...
# 14  Secret Stairways - Enchantment of the Ring (19...
# 15  Bacchia Neraida - Dionysos (1997) (Black Ambie...
# 16  Erang - A SEASON OF FROST / LEAVES / SAND / BL...
# 17  Aindulmedir - The Lunar Lexicon (2019) (Dark A...
# 18  Old Tower - The Last Eidolon (2020) (Old-Schoo...
# 19  Mordraaneth - The Taverns in the Land of Ashes...
# 20  Monastery - The Garden Of Abandon (2019) (Dung...
# 21  Secret Stairways - Turning Point (1999) (Dunge...
# 22  December&#39;s Fire ‎- Across The Sorrowfields...
# 23  Ortnit - Ortnit (2022) (Dungeon Synth) [OFFICI...
# 24  Quest Master - Lost Songs of Distant Realms [C...
#
#                                           description                  date  \
# 0   Welcome on The Dungeon Synth Archives ! Here y...  2015-11-21T13:20:19Z
# 1   Artist : Knights of Nvrul Album : Knightronaut...  2022-12-06T17:42:37Z
# 2   Artist : Vindkaldr Album : Ambient I Year : 20...  2017-01-11T19:45:10Z
# 3   Artist : Vindkaldr Album : Enchantments Of Old...  2017-01-13T17:43:11Z
# 4   Artist : Tales Under The Oak Album : The Toad ...  2022-06-07T17:16:22Z
# 5   THUMBNAIL ART BY WILHELM STEUERWALDT *Örnatorp...  2019-12-09T21:30:10Z
# 6   Artist : Old Tower Album : Tales of the Mad Mo...  2022-09-26T16:43:05Z
# 7   Artist : Frost Clad Album : The Bastion of Pin...  2022-11-17T19:22:08Z
# 8   Artist : Fief Album : II Year : 2016 Genre : D...  2017-02-16T11:07:08Z
# 9   Artist : Thangorodrim Album : Taur​-​nu​-​Fuin...  2016-07-02T15:31:21Z
# 10  Artist : Galdur Album : Age of Legends Year : ...  2016-07-12T23:44:16Z
# 11  Artist: Frér Album: Crepuscular Glare Of Wisdo...  2022-08-28T19:15:50Z
# 12  Artist : DIM Album : Compendium Reliquiae Year...  2022-01-12T18:31:31Z
# 13  Artist : Depressive Silence Album : Depressive...  2017-09-02T12:01:46Z
# 14  Artist : Secret Stairways Album : Enchantment ...  2016-07-20T18:15:19Z
# 15  Artist : Bacchia Neraida Album : Dionysos Year...  2017-07-29T13:54:32Z
# 16  Artist : Erang Album : 10 Years Pentalogy Year...  2022-12-02T20:00:53Z
# 17  Artist : Aindulmedir Album : The Lunar Lexicon...  2019-03-02T11:35:05Z
# 18  Artist : Old Tower Album : The Last Eidolon Ye...  2022-10-15T09:14:36Z
# 19  Artist : Mordraaneth Album : The Taverns in th...  2016-07-25T20:20:56Z
# 20  Artist : Monastery Album : The Garden Of Aband...  2019-11-12T16:43:22Z
# 21  Artist : Secret Stairways Album : Turning Poin...  2016-07-21T13:30:03Z
# 22  Artist : December's Fire ‎ Album : Across The ...  2017-04-06T15:43:00Z
# 23  Artist : Ortnit (side project of Thomas Helm f...  2022-09-15T16:45:12Z
# 24  Artist : Quest Master Album : Lost Songs of Di...  2020-04-05T14:35:24Z
#
#                                                  link
# 0   https://www.youtube.com/watch?v=UChmm356a5qe1l...
# 1         https://www.youtube.com/watch?v=qqDyoqB7Nj0
# 2         https://www.youtube.com/watch?v=Pe8eBeGtJ_w
# 3         https://www.youtube.com/watch?v=1LbciQTAjJw
# 4         https://www.youtube.com/watch?v=dI7tjPGEz7U
# 5         https://www.youtube.com/watch?v=x8TGp13ZzIA
# 6         https://www.youtube.com/watch?v=gBmz4O41jfc
# 7         https://www.youtube.com/watch?v=BkDyoi-eFUw
# 8         https://www.youtube.com/watch?v=DffQVP6UqVQ
# 9         https://www.youtube.com/watch?v=1lpf-nQFzJ4
# 10        https://www.youtube.com/watch?v=uTpRQS1LDiw
# 11        https://www.youtube.com/watch?v=ngRcnobJxi4
# 12        https://www.youtube.com/watch?v=fpz7GNig8IU
# 13        https://www.youtube.com/watch?v=OxgVmpAk538
# 14        https://www.youtube.com/watch?v=XKSu-wZChcQ
# 15        https://www.youtube.com/watch?v=eKguSG6XAG8
# 16        https://www.youtube.com/watch?v=6aTalupHHrU
# 17        https://www.youtube.com/watch?v=2lS_Y-aNJwk
# 18        https://www.youtube.com/watch?v=66HmBxrTlrQ
# 19        https://www.youtube.com/watch?v=ZLqAdISGYR8
# 20        https://www.youtube.com/watch?v=xEXjwm-xLSw
# 21        https://www.youtube.com/watch?v=E9R-vzIe8x0
# 22        https://www.youtube.com/watch?v=UzTqkmN79dU
# 23        https://www.youtube.com/watch?v=uwwIB5uheNo
# 24        https://www.youtube.com/watch?v=lklHS1G9E-M

# %% [markdown]
# ### Next Steps
# - [x] How to present results in a better way?
#     e.g.: video name, views, date, channel name, description, url
# - [x] REMOVE KEYS AND AUTH FILES (CLIENT SECRET JSON), ADD GITIGNORE -> THEN RESTART REPO FROM SCRATCH
# - [x] Query videos, channels and playlist. Present results separately
# - [ ] Compare Results through API request vs:
#     a) Incognito YT Search
#     b) Logged in YT Search
# - [ ] Document Results and publish somewhere (blog?)
