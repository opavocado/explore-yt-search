# %% [markdown]
# # Experiment: 1. API Exploration
#
# Dependencies
# - google-api-python-client
# - google-auth-oauthlib
# - google-auth-httplib
#
# Requirements
# - Create a [Google API Console Project and API Key](https://developers.google.com/youtube/v3/quickstart/python)

# %%
# This is an example that was obtained from here:
# https://medium.com/mcd-unison/youtube-data-api-v3-in-python-tutorial-with-examples-e829a25d2ebd#5999

# IMPORTS
import json
import numpy as np
import pandas as pd
# API client library
import googleapiclient.discovery

# API information
api_service_name = "youtube"
api_version = "v3"

# API key
with open('dev.key') as f:
    DEVELOPER_KEY = f.readline()

# API client
youtube = googleapiclient.discovery.build(
    api_service_name, 
    api_version, 
    developerKey = DEVELOPER_KEY)

# Query String
query_string = "foglord"
    
# Query Paramters
# TODO

# 'request' variable is the only thing you must change
# depending on the resource and method you need to use
# in your query
request = youtube.search().list(
    part="snippet",
    maxResults=25,
    q=query_string
)

# Query execution
response = request.execute()

# %%
# Extract Results
total_results = response["pageInfo"]["totalResults"]
next_page_token = response["nextPageToken"]
items = response["items"]


# Print Results
print("Total Results: " + str(total_results))
result_list = []

for i in items:
    # Extract base data (only for VIDEOS - TODO: handle playlist and channels)
    if(i["id"]["kind"] == "youtube#video"):
        video_id = i["id"]["videoId"]

        # Extract Snippet
        snippet = i["snippet"]
        channel_id = snippet["channelId"]
        channel_title = snippet["channelTitle"]
        channel_link = "https://www.youtube.com/channel/" + str(channel_id)
        title = snippet["title"]
        description = snippet["description"]
        date = snippet["publishedAt"]
        link = "https://www.youtube.com/watch?v=" + str(video_id)

        # Add to List
        result_list.append({
            'id': video_id, 
            'channel_id': channel_id, 
            'channel_title': channel_title, 
            'channel_link': channel_link,
            'title': title, 
            'description': description, 
            'date': date, 
            'link': link
        })

result_df = pd.DataFrame(result_list)
result_df
# Out:
# Total Results: 3200
#              id                channel_id                       channel_title  \
# 0   jFJIXHUBqBM  UCV-RyRTJZym-lksT9VG8E-g                        In The Woods
# 1   bgMWPvAVskg  UChmm356a5qe1luUsoatAgjA          The Dungeon Synth Archives
# 2   wFWVHexwHWA  UCXqJytwfS2aDGlqpvRYa50A                       Out of Season
# 3   aN5cbw10-QE  UChmm356a5qe1luUsoatAgjA          The Dungeon Synth Archives
# 4   4R2vK_5luW8  UChmm356a5qe1luUsoatAgjA          The Dungeon Synth Archives
# 5   lM-QTl68y3M  UCOcHCxCsOJPZBtsF9FkfoLw                       Into Eternity
# 6   PiL7KF4cQVs  UCXqJytwfS2aDGlqpvRYa50A                       Out of Season
# 7   AQCOWWp2-yE  UCOcHCxCsOJPZBtsF9FkfoLw                       Into Eternity
# 8   YcVO3apo59w  UCOI7q-1XKouuJWV5oOxZkGw                       Dungeon Synth
# 9   JMKPKOV0DgA  UCZTM33z0lyU4p343XLAaz7A              Northeast DungeonSiege
# 10  5USFa5wTpKo  UCOcHCxCsOJPZBtsF9FkfoLw                       Into Eternity
# 11  UzsOFpyNNi8  UCOcHCxCsOJPZBtsF9FkfoLw                       Into Eternity
# 12  R2iLg6rFk6U  UCXqJytwfS2aDGlqpvRYa50A                       Out of Season
# 13  YKRx8zvrfxQ  UCmlRAoX7csUVRgvEXk-dQOA                          Teyaotlani
# 14  cZWhpM66-P4  UChM54xOEDPmpuO0bg8bU7cw                 Black Metal Updates
# 15  yQuCHgzwfvg  UChM54xOEDPmpuO0bg8bU7cw                 Black Metal Updates
# 16  Ioi0WsJUyuc  UCmlRAoX7csUVRgvEXk-dQOA                          Teyaotlani
# 17  UsKAxhoLmFc  UCqspjSFW5ooSZQmiy1kloog                           Darien D.
# 18  J_xOSENKtCg  UCfKex4KWo9EGqnyMaxe0HCQ                           melefic1e
# 19  FftAgliiUj4  UCly2C4ucR-jiuNqX_CpMR9A                        RunawayBay80
# 20  XQuYjpU61oc  UC70RFURM2TFTePHdqsHqq9Q  Rune X -Natural Northern Darkness-
# 21  SimmGJaOva0  UCj6ESuFuzCfN4EcsYhQPwKQ                     Foglord - Topic
# 22  9HKsKKD2nJM  UCqspjSFW5ooSZQmiy1kloog                           Darien D.
#
#                                          channel_link  \
# 0   https://www.youtube.com/channel/UCV-RyRTJZym-l...
# 1   https://www.youtube.com/channel/UChmm356a5qe1l...
# 2   https://www.youtube.com/channel/UCXqJytwfS2aDG...
# 3   https://www.youtube.com/channel/UChmm356a5qe1l...
# 4   https://www.youtube.com/channel/UChmm356a5qe1l...
# 5   https://www.youtube.com/channel/UCOcHCxCsOJPZB...
# 6   https://www.youtube.com/channel/UCXqJytwfS2aDG...
# 7   https://www.youtube.com/channel/UCOcHCxCsOJPZB...
# 8   https://www.youtube.com/channel/UCOI7q-1XKouuJ...
# 9   https://www.youtube.com/channel/UCZTM33z0lyU4p...
# 10  https://www.youtube.com/channel/UCOcHCxCsOJPZB...
# 11  https://www.youtube.com/channel/UCOcHCxCsOJPZB...
# 12  https://www.youtube.com/channel/UCXqJytwfS2aDG...
# 13  https://www.youtube.com/channel/UCmlRAoX7csUVR...
# 14  https://www.youtube.com/channel/UChM54xOEDPmpu...
# 15  https://www.youtube.com/channel/UChM54xOEDPmpu...
# 16  https://www.youtube.com/channel/UCmlRAoX7csUVR...
# 17  https://www.youtube.com/channel/UCqspjSFW5ooSZ...
# 18  https://www.youtube.com/channel/UCfKex4KWo9EGq...
# 19  https://www.youtube.com/channel/UCly2C4ucR-jiu...
# 20  https://www.youtube.com/channel/UC70RFURM2TFTe...
# 21  https://www.youtube.com/channel/UCj6ESuFuzCfN4...
# 22  https://www.youtube.com/channel/UCqspjSFW5ooSZ...
#
#                                                 title  \
# 0   Fog Castle/Foglord/Fogweaver - In the Kingdom ...
# 1   Foglord - Celestial (2015) (Atmospheric Dungeo...
# 2   FOGLORD &quot;Winter Dreams&quot; (Full Album)...
# 3   Foglord - New Realms and Forgotten Lands (2013...
# 4   Foglord - Tales From The Woods (2020) (Dungeon...
# 5                Foglord - The Great Forest Gathering
# 6   FOGLORD &quot;New Realms &amp; Forgotten Lands...
# 7                 Foglord - First Light Upon the Land
# 8                         Foglord - Autumnal Solitude
# 9              Northeast Dungeon Siege MMXX | Foglord
# 10                        Foglord - Autumnal Solitude
# 11            Foglord - The Dream of a Winter s Night
# 12  FOG CASTLE / FOGWEAVER / FOGLORD &quot;In the ...
# 13                          Foglord - A Woodland Tale
# 14              Foglord - Lost in an Old Dream (2014)
# 15                      Foglord - Night Spirit (2014)
# 16       Foglord - The Old Wanderers Tale (Full Demo)
# 17                                Foglord - Stillness
# 18                      foglord  -  mountains of mist
# 19                      Foglord - The Healing Gardens
# 20                             Foglord - Night Spirit
# 21                           Floating Under the Stars
# 22              Foglord - Tales From The Woods (2020)
#
#                                           description                  date  \
# 0   Fantasy Ambient/Dungeon Synth from USA. Fog Ca...  2020-11-03T18:40:18Z
# 1   Artist : Foglord Album : Celestial Year : 2015...  2016-12-28T17:11:39Z
# 2   This was our very first release back in 2016! ...  2020-12-17T22:50:58Z
# 3   Artist : Foglord Album : In a Darkened Age Yea...  2016-12-02T09:56:06Z
# 4   Artist : Foglord Album : Tales From The Woods ...  2020-07-15T17:09:16Z
# 5   This song was taken from the split ''Fimbulwin...  2022-12-07T19:07:14Z
# 6   https://www.outofseasonlabel.com https://foglo...  2019-10-23T18:11:04Z
# 7   This song was taken from the split ''Fimbulwin...  2022-12-07T19:05:33Z
# 8   Sorry for the delay guys, but here we are agai...  2015-03-28T15:35:50Z
# 9   Foglord performance at Northeast Dungeon Siege...  2020-07-07T00:33:58Z
# 10  This song was taken from the split ''Fimbulwin...  2022-12-07T19:08:30Z
# 11  This song was taken from the split ''Fimbulwin...  2022-12-07T19:11:21Z
# 12  Three wizards enter the kingdom of fog... CD e...  2021-07-14T16:53:38Z
# 13  Album: Journey of the Spirits Country: United ...  2015-10-14T18:03:36Z
# 14  Medieval / Dungeon Synth from USA From the "Jo...  2014-08-01T18:23:28Z
# 15  Medieval / Dungeon Synth from USA From the "De...  2014-07-08T23:53:11Z
# 16  País: United States Género: Dark Ambient, Dung...  2019-02-11T22:55:57Z
# 17  In the stillness of the winter cold.. https://...  2019-03-20T22:47:27Z
# 18                                       Description.  2019-02-09T18:59:57Z
# 19                  From "The Healing Gardens", 2017.  2017-10-18T10:44:06Z
# 20  Foglord - Dungeon Synth/Medieval Ambient - Nig...  2016-04-07T17:55:53Z
# 21  Provided to YouTube by DistroKid Floating Unde...  2021-03-24T22:37:56Z
# 22  The title track from the new Foglord album "Ta...  2020-05-08T17:00:34Z
#
#                                            link
# 0   https://www.youtube.com/watch?v=jFJIXHUBqBM
# 1   https://www.youtube.com/watch?v=bgMWPvAVskg
# 2   https://www.youtube.com/watch?v=wFWVHexwHWA
# 3   https://www.youtube.com/watch?v=aN5cbw10-QE
# 4   https://www.youtube.com/watch?v=4R2vK_5luW8
# 5   https://www.youtube.com/watch?v=lM-QTl68y3M
# 6   https://www.youtube.com/watch?v=PiL7KF4cQVs
# 7   https://www.youtube.com/watch?v=AQCOWWp2-yE
# 8   https://www.youtube.com/watch?v=YcVO3apo59w
# 9   https://www.youtube.com/watch?v=JMKPKOV0DgA
# 10  https://www.youtube.com/watch?v=5USFa5wTpKo
# 11  https://www.youtube.com/watch?v=UzsOFpyNNi8
# 12  https://www.youtube.com/watch?v=R2iLg6rFk6U
# 13  https://www.youtube.com/watch?v=YKRx8zvrfxQ
# 14  https://www.youtube.com/watch?v=cZWhpM66-P4
# 15  https://www.youtube.com/watch?v=yQuCHgzwfvg
# 16  https://www.youtube.com/watch?v=Ioi0WsJUyuc
# 17  https://www.youtube.com/watch?v=UsKAxhoLmFc
# 18  https://www.youtube.com/watch?v=J_xOSENKtCg
# 19  https://www.youtube.com/watch?v=FftAgliiUj4
# 20  https://www.youtube.com/watch?v=XQuYjpU61oc
# 21  https://www.youtube.com/watch?v=SimmGJaOva0
# 22  https://www.youtube.com/watch?v=9HKsKKD2nJM

# %% [markdown]
# ### Next Steps
# - [x] How to present results in a better way?
#     e.g.: video name, views, date, channel name, description, url
# - [ ] REMOVE KEYS AND AUTH FILES (CLIENT SECRET JSON), ADD GITIGNORE -> THEN RESTART REPO FROM SCRATCH
# - [ ] Query videos, channels and playlist. Present results separately
# - [ ] Compare Results through API request vs:
#     a) Incognito YT Search
#     b) Logged in YT Search
# - [ ] Document Results and publish somewhere (blog?)
