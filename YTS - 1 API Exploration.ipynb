# %% [markdown]
# # Experiment: 1. API Exploration
#
# Dependencies
# - google-api-python-client
# - google-auth-oauthlib
# - google-auth-httplib
#
# Requirements
# - Create a [Google API Console Project and API Key](https://developers.google.com/youtube/v3/quickstart/python)

# %%
# This is an example that was obtained from here:
# https://medium.com/mcd-unison/youtube-data-api-v3-in-python-tutorial-with-examples-e829a25d2ebd#5999

# IMPORTS
import json
import numpy as np
import pandas as pd
# API client library
import googleapiclient.discovery

# API information
api_service_name = "youtube"
api_version = "v3"

# API key
DEVELOPER_KEY = "AIzaSyAp-hNHl8GVd6D38nyrHjReMpB5Vlb_myw"

# API client
youtube = googleapiclient.discovery.build(
    api_service_name, 
    api_version, 
    developerKey = DEVELOPER_KEY)

# Query String
query_string = "foglord"
    
# Query Paramters
# TODO

# 'request' variable is the only thing you must change
# depending on the resource and method you need to use
# in your query
request = youtube.search().list(
    part="snippet",
    maxResults=25,
    q=query_string
)

# Query execution
response = request.execute()

# %%
# Extract Results
total_results = response["pageInfo"]["totalResults"]
next_page_token = response["nextPageToken"]
items = response["items"]


# Print Results
print("Total Results: " + str(total_results))
result_list = []

for i in items:
    # Extract base data (only for VIDEOS - TODO: handle playlist and channels)
    if(i["id"]["kind"] == "youtube#video"):
        video_id = i["id"]["videoId"]

        # Extract Snippet
        snippet = i["snippet"]
        channel_id = snippet["channelId"]
        channel_title = snippet["channelTitle"]
        channel_link = "https://www.youtube.com/channel/" + str(channel_id)
        title = snippet["title"]
        description = snippet["description"]
        date = snippet["publishedAt"]
        link = "https://www.youtube.com/watch?v=" + str(video_id)

        # Add to List
        result_list.append({
            'id': video_id, 
            'channel_id': channel_id, 
            'channel_title': channel_title, 
            'channel_link': channel_link,
            'title': title, 
            'description': description, 
            'date': date, 
            'link': link
        })

result_df = pd.DataFrame(result_list)
result_df
# Out:
# Total Results: 3153
#              id                channel_id                       channel_title  \
# 0   bgMWPvAVskg  UChmm356a5qe1luUsoatAgjA          The Dungeon Synth Archives
# 1   jFJIXHUBqBM  UCV-RyRTJZym-lksT9VG8E-g                        In The Woods
# 2   wFWVHexwHWA  UCXqJytwfS2aDGlqpvRYa50A                       Out of Season
# 3   4R2vK_5luW8  UChmm356a5qe1luUsoatAgjA          The Dungeon Synth Archives
# 4   aN5cbw10-QE  UChmm356a5qe1luUsoatAgjA          The Dungeon Synth Archives
# 5   PiL7KF4cQVs  UCXqJytwfS2aDGlqpvRYa50A                       Out of Season
# 6   JMKPKOV0DgA  UCZTM33z0lyU4p343XLAaz7A              Northeast DungeonSiege
# 7   R2iLg6rFk6U  UCXqJytwfS2aDGlqpvRYa50A                       Out of Season
# 8   1wgmCLGZXAg  UCd12jOHxan2JzSC5ce91C1g                       Music Comrade
# 9   yQuCHgzwfvg  UChM54xOEDPmpuO0bg8bU7cw                 Black Metal Updates
# 10  YcVO3apo59w  UCOI7q-1XKouuJWV5oOxZkGw                       Dungeon Synth
# 11  XQuYjpU61oc  UC70RFURM2TFTePHdqsHqq9Q  Rune X -Natural Northern Darkness-
# 12  UsKAxhoLmFc  UCqspjSFW5ooSZQmiy1kloog                           Darien D.
# 13  uO3Ci7VvAJk  UCC9PNGm-UhX7sM2kVOV0thw                     ThoseHappyBeats
# 14  cZWhpM66-P4  UChM54xOEDPmpuO0bg8bU7cw                 Black Metal Updates
# 15  J_xOSENKtCg  UCfKex4KWo9EGqnyMaxe0HCQ                           melefic1e
# 16  Dgqd9r3Gn_c  UCXqJytwfS2aDGlqpvRYa50A                       Out of Season
# 17  YKRx8zvrfxQ  UCmlRAoX7csUVRgvEXk-dQOA                          Teyaotlani
# 18  plHm2c0rDmQ  UC3KL7X-fjuq5Jp-PfhwdmWQ                                 Vit
# 19  REGLnm0AA5I  UCDZUyjSZSTuCPTJh0RhkOKQ                           LORD APEX
# 20  SimmGJaOva0  UCj6ESuFuzCfN4EcsYhQPwKQ                     Foglord - Topic
# 21  FftAgliiUj4  UCly2C4ucR-jiuNqX_CpMR9A                        RunawayBay80
# 22  9HKsKKD2nJM  UCqspjSFW5ooSZQmiy1kloog                           Darien D.
# 23  Ioi0WsJUyuc  UCmlRAoX7csUVRgvEXk-dQOA                          Teyaotlani
#
#                                          channel_link  \
# 0   https://www.youtube.com/channel/UChmm356a5qe1l...
# 1   https://www.youtube.com/channel/UCV-RyRTJZym-l...
# 2   https://www.youtube.com/channel/UCXqJytwfS2aDG...
# 3   https://www.youtube.com/channel/UChmm356a5qe1l...
# 4   https://www.youtube.com/channel/UChmm356a5qe1l...
# 5   https://www.youtube.com/channel/UCXqJytwfS2aDG...
# 6   https://www.youtube.com/channel/UCZTM33z0lyU4p...
# 7   https://www.youtube.com/channel/UCXqJytwfS2aDG...
# 8   https://www.youtube.com/channel/UCd12jOHxan2Jz...
# 9   https://www.youtube.com/channel/UChM54xOEDPmpu...
# 10  https://www.youtube.com/channel/UCOI7q-1XKouuJ...
# 11  https://www.youtube.com/channel/UC70RFURM2TFTe...
# 12  https://www.youtube.com/channel/UCqspjSFW5ooSZ...
# 13  https://www.youtube.com/channel/UCC9PNGm-UhX7s...
# 14  https://www.youtube.com/channel/UChM54xOEDPmpu...
# 15  https://www.youtube.com/channel/UCfKex4KWo9EGq...
# 16  https://www.youtube.com/channel/UCXqJytwfS2aDG...
# 17  https://www.youtube.com/channel/UCmlRAoX7csUVR...
# 18  https://www.youtube.com/channel/UC3KL7X-fjuq5J...
# 19  https://www.youtube.com/channel/UCDZUyjSZSTuCP...
# 20  https://www.youtube.com/channel/UCj6ESuFuzCfN4...
# 21  https://www.youtube.com/channel/UCly2C4ucR-jiu...
# 22  https://www.youtube.com/channel/UCqspjSFW5ooSZ...
# 23  https://www.youtube.com/channel/UCmlRAoX7csUVR...
#
#                                                 title  \
# 0   Foglord - Celestial (2015) (Atmospheric Dungeo...
# 1   Fog Castle/Foglord/Fogweaver - In the Kingdom ...
# 2   FOGLORD &quot;Winter Dreams&quot; (Full Album)...
# 3   Foglord - Tales From The Woods (2020) (Dungeon...
# 4   Foglord - New Realms and Forgotten Lands (2013...
# 5   FOGLORD &quot;New Realms &amp; Forgotten Lands...
# 6              Northeast Dungeon Siege MMXX | Foglord
# 7   FOG CASTLE / FOGWEAVER / FOGLORD &quot;In the ...
# 8   Fog Castle/Foglord/Fogweaver - In the Kingdom ...
# 9                       Foglord - Night Spirit (2014)
# 10                        Foglord - Autumnal Solitude
# 11                             Foglord - Night Spirit
# 12                                Foglord - Stillness
# 13  Fog Castle/Foglord/Fogweaver  : In the Kingdom...
# 14              Foglord - Lost in an Old Dream (2014)
# 15                      foglord  -  mountains of mist
# 16  FOGLORD &quot;Tales From The Woods&quot; (Full...
# 17                          Foglord - A Woodland Tale
# 18                    Foglord - Light in the Mountain
# 19  LORD APEX &amp; V DON - LONDON FOG ft. WESTSID...
# 20                           Floating Under the Stars
# 21                      Foglord - The Healing Gardens
# 22              Foglord - Tales From The Woods (2020)
# 23       Foglord - The Old Wanderers Tale (Full Demo)
#
#                                           description                  date  \
# 0   Artist : Foglord Album : Celestial Year : 2015...  2016-12-28T17:11:39Z
# 1   Fantasy Ambient/Dungeon Synth from USA. Fog Ca...  2020-11-03T18:40:18Z
# 2   This was our very first release back in 2016! ...  2020-12-17T22:50:58Z
# 3   Artist : Foglord Album : Tales From The Woods ...  2020-07-15T17:09:16Z
# 4   Artist : Foglord Album : In a Darkened Age Yea...  2016-12-02T09:56:06Z
# 5   https://www.outofseasonlabel.com https://foglo...  2019-10-23T18:11:04Z
# 6   Foglord performance at Northeast Dungeon Siege...  2020-07-07T00:33:58Z
# 7   Three wizards enter the kingdom of fog... CD e...  2021-07-14T16:53:38Z
# 8   fantasy_ambient #dungeon_synth Track list: 00:...  2021-05-26T18:00:00Z
# 9   Medieval / Dungeon Synth from USA From the "De...  2014-07-08T23:53:11Z
# 10  Sorry for the delay guys, but here we are agai...  2015-03-28T15:35:50Z
# 11  Foglord - Dungeon Synth/Medieval Ambient - Nig...  2016-04-07T17:55:53Z
# 12  In the stillness of the winter cold.. https://...  2019-03-20T22:47:27Z
# 13  Dungeon synth from the world of Earthsea. Fog ...  2022-10-24T15:00:38Z
# 14  Medieval / Dungeon Synth from USA From the "Jo...  2014-08-01T18:23:28Z
# 15                                       Description.  2019-02-09T18:59:57Z
# 16  Linktr.ee/outofseason Support the artist here:...  2021-03-05T03:20:27Z
# 17  Album: Journey of the Spirits Country: United ...  2015-10-14T18:03:36Z
# 18  from the split "In the Kingdom of Fog" Bandcam...  2020-11-11T16:53:55Z
# 19  "London Fog" Available to stream/download here...  2020-12-20T16:15:08Z
# 20  Provided to YouTube by DistroKid Floating Unde...  2021-03-24T22:37:56Z
# 21                  From "The Healing Gardens", 2017.  2017-10-18T10:44:06Z
# 22  The title track from the new Foglord album "Ta...  2020-05-08T17:00:34Z
# 23  País: United States Género: Dark Ambient, Dung...  2019-02-11T22:55:57Z
#
#                                            link
# 0   https://www.youtube.com/watch?v=bgMWPvAVskg
# 1   https://www.youtube.com/watch?v=jFJIXHUBqBM
# 2   https://www.youtube.com/watch?v=wFWVHexwHWA
# 3   https://www.youtube.com/watch?v=4R2vK_5luW8
# 4   https://www.youtube.com/watch?v=aN5cbw10-QE
# 5   https://www.youtube.com/watch?v=PiL7KF4cQVs
# 6   https://www.youtube.com/watch?v=JMKPKOV0DgA
# 7   https://www.youtube.com/watch?v=R2iLg6rFk6U
# 8   https://www.youtube.com/watch?v=1wgmCLGZXAg
# 9   https://www.youtube.com/watch?v=yQuCHgzwfvg
# 10  https://www.youtube.com/watch?v=YcVO3apo59w
# 11  https://www.youtube.com/watch?v=XQuYjpU61oc
# 12  https://www.youtube.com/watch?v=UsKAxhoLmFc
# 13  https://www.youtube.com/watch?v=uO3Ci7VvAJk
# 14  https://www.youtube.com/watch?v=cZWhpM66-P4
# 15  https://www.youtube.com/watch?v=J_xOSENKtCg
# 16  https://www.youtube.com/watch?v=Dgqd9r3Gn_c
# 17  https://www.youtube.com/watch?v=YKRx8zvrfxQ
# 18  https://www.youtube.com/watch?v=plHm2c0rDmQ
# 19  https://www.youtube.com/watch?v=REGLnm0AA5I
# 20  https://www.youtube.com/watch?v=SimmGJaOva0
# 21  https://www.youtube.com/watch?v=FftAgliiUj4
# 22  https://www.youtube.com/watch?v=9HKsKKD2nJM
# 23  https://www.youtube.com/watch?v=Ioi0WsJUyuc

# %% [markdown]
# ### Next Steps
# - [x] How to present results in a better way?
#     e.g.: video name, views, date, channel name, description, url
# - [ ] Query videos, channels and playlist. Present results separately
# - [ ] Compare Results through API request vs:
#     a) Incognito YT Search
#     b) Logged in YT Search
# - [ ] Document Results and publish somewhere (blog?)
